# %%
from dotenv import load_dotenv
from openai import OpenAI
import gradio as gr
from PyPDF2 import PdfReader
from IPython.display import Markdown, display
import os
from pydantic import BaseModel

file_path = "/Users/amir/Desktop/GitHub/new_project/me/Profile.pdf"
summary_path = "/Users/amir/Desktop/GitHub/new_project/me/summary.txt"

# %%
load_dotenv()

openai_client = OpenAI()
gemini_client = OpenAI(api_key=os.getenv("GEMENI_API_KEY"),base_url="https://generativelanguage.googleapis.com/v1beta/openai/")

# %%
linkedin = ""

reader = PdfReader(file_path)
for page in reader.pages:
    linkedin += page.extract_text()

display(Markdown(linkedin))
# Out:
#
# Contact
# ah.ghadami75@gmail.com
# www.linkedin.com/in/
# amirhosseinghadami  (LinkedIn)
# github.com/AmirHosseinGhadami
# (Other)
# scholar.google.ca/citations
# (Personal)
# Top Skills
# Transformers
# Research Skills
# Recommender Systems
# Languages
# Persian  (Native or Bilingual)
# English  (Professional Working)
# Certifications
# R Programming
# Sample-based Learning Methods
# Python 3 Programming
# Specialization
# SQL for Data Science
# Reinforcement Learning
# Specialization
# Publications
# TAVo: Tor Application Detection with
# Voting Critic
# TriDeepRec: A Hybrid Deep
# Learning Approach to Content and
# Behavior-based Recommendation
# Systems
# CAERS-CF: enhancing convolutional
# autoencoder recommendations
# through collaborative filteringAmir Ghadami
# ML & Generative AI Engineer | M.Sc. CS, uOttawa
# Canada
# Summary
# I’m a Machine Learning Engineer with an MSc in Computer Science
# from uOttawa and a focus on deep learning, MLOps, and LLMs.
# I’ve published research on recommender systems and built AI-
# driven applications like LLM agents, RAG pipelines, and automated
# summarization tools. Skilled in PyTorch, TensorFlow, Hugging Face,
# Docker, and GCP, I enjoy building end-to-end ML systems that solve
# real-world problems. I’m currently seeking ML roles where I can
# apply my skills and grow with impactful teams.
# Experience
# University of Ottawa
# 2 years 10 months
# Machine learning Research Assistant
# September 2022 - June 2025  (2 years 10 months)
# Ontario, Canada
# Teaching Assistant
# April 2024 - August 2024  (5 months)
# Ottawa, Ontario, Canada
# Teaching Assistant
# September 2023 - December 2023  (4 months)
# Ottawa, Ontario, Canada
# Teacher Assistant
# October 2022 - December 2022  (3 months)
# Data Co Lab
# 3 years 1 month
# Data Scientist
# June 2019 - May 2022  (3 years)
# Data Science Internship (AI/ML)
# May 2019 - June 2019  (2 months)
#   Page 1 of 2
# Education
# University of Ottawa
# Master of computer science , Artificial Intelligence  · (August 2022 - June 2025)
# Azad University (IAU)
# Bachelor's degree, Computer Software Engineering  · (2016 - 2021)
#   Page 2 of 2

# %%
with open(summary_path, "r") as f:
    summary = f.read()

display(Markdown(summary))
# Out:
# Amir Ghadami is a Computer Science researcher based in Ottawa, Canada, holding a Master's degree from the University of Ottawa with an exceptional GPA of 3.96/4.0, supervised by Prof. Thomas Tran. His master's research focused on hybrid deep learning architectures for personalized recommendation systems, integrating convolutional autoencoders, transformers, and collaborative filtering to unify content- and behavior-based user modeling. This work resulted in two first-author publications in top-tier journals — User Modeling and User-Adapted Interaction (UMUAI) and Knowledge and Information Systems (KAIS) — both among the leading venues in recommender systems and personalization research, a rare and impressive achievement at the master's level.
# Beyond his academic work, Amir has demonstrated strong applied research skills through several notable projects — including DealMind, a modular multi-agent RAG system for real-time product discovery; VoyageAI, a dual-agent multimodal travel assistant; and PersonaRAG, a career-aware chatbot built on retrieval-augmented generation with semantic search. His research interests span NLP, large language models, RAG, personalization, recommender systems, and agentic AI. Currently targeting a PhD for September 2027 at world-class institutions including UWaterloo, UAlberta, UBC, Mila, ETH Zurich, EPFL, UCL, and Oxford, Amir's defining goals for 2026 are ambitious across every dimension — securing a high-paying AI industry role, obtaining Canadian permanent residency, identifying the best possible PhD supervisor at a top university worldwide, saving $20,000, and getting into the best shape of his life. A man on a mission on all fronts. 💪

# %%
name = "Amir Ghadami"

system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
def chat(message, history):
    messages = [{'role': 'system', 'content': system_prompt}] + history + [{'role': 'user', 'content': message}]
    response = openai_client.chat.completions.create(model='gpt-4o-mini', messages=messages)
    return response.choices[0].message.content

demo = gr.ChatInterface(chat)

demo.launch()
# Out:
# /Users/amir/Desktop/GitHub/new_project/.venv/lib/python3.13/site-packages/gradio/chat_interface.py:347: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   self.chatbot = Chatbot(
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
def evaluate(reply, message, history) -> Evaluation:
    messages = [{'role': 'system', 'content': evaluator_system_prompt}] + [{'role': 'user', 'content': evaluator_user_prompt(reply, message, history)}]
    response = openai_client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=messages,
        response_format=Evaluation
    )
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai_client.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
messages
# Out:
# [{'role': 'system',
#   'content': "You are acting as Amir Ghadami. You are answering questions on Amir Ghadami's website, particularly questions related to Amir Ghadami's career, background, skills and experience. Your responsibility is to represent Amir Ghadami for interactions on the website as faithfully as possible. You are given a summary of Amir Ghadami's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nAmir Ghadami is a Computer Science researcher based in Ottawa, Canada, holding a Master's degree from the University of Ottawa with an exceptional GPA of 3.96/4.0, supervised by Prof. Thomas Tran. His master's research focused on hybrid deep learning architectures for personalized recommendation systems, integrating convolutional autoencoders, transformers, and collaborative filtering to unify content- and behavior-based user modeling. This work resulted in two first-author publications in top-tier journals — User Modeling and User-Adapted Interaction (UMUAI) and Knowledge and Information Systems (KAIS) — both among the leading venues in recommender systems and personalization research, a rare and impressive achievement at the master's level.\nBeyond his academic work, Amir has demonstrated strong applied research skills through several notable projects — including DealMind, a modular multi-agent RAG system for real-time product discovery; VoyageAI, a dual-agent multimodal travel assistant; and PersonaRAG, a career-aware chatbot built on retrieval-augmented generation with semantic search. His research interests span NLP, large language models, RAG, personalization, recommender systems, and agentic AI. Currently targeting a PhD for September 2027 at world-class institutions including UWaterloo, UAlberta, UBC, Mila, ETH Zurich, EPFL, UCL, and Oxford, Amir's defining goals for 2026 are ambitious across every dimension — securing a high-paying AI industry role, obtaining Canadian permanent residency, identifying the best possible PhD supervisor at a top university worldwide, saving $20,000, and getting into the best shape of his life. A man on a mission on all fronts. 💪\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nah.ghadami75@gmail.com\nwww.linkedin.com/in/\namirhosseinghadami  (LinkedIn)\ngithub.com/AmirHosseinGhadami\n(Other)\nscholar.google.ca/citations\n(Personal)\nTop Skills\nTransformers\nResearch Skills\nRecommender Systems\nLanguages\nPersian  (Native or Bilingual)\nEnglish  (Professional Working)\nCertifications\nR Programming\nSample-based Learning Methods\nPython 3 Programming\nSpecialization\nSQL for Data Science\nReinforcement Learning\nSpecialization\nPublications\nTAVo: Tor Application Detection with\nVoting Critic\nTriDeepRec: A Hybrid Deep\nLearning Approach to Content and\nBehavior-based Recommendation\nSystems\nCAERS-CF: enhancing convolutional\nautoencoder recommendations\nthrough collaborative filteringAmir Ghadami\nML & Generative AI Engineer | M.Sc. CS, uOttawa\nCanada\nSummary\nI’m a Machine Learning Engineer with an MSc in Computer Science\nfrom uOttawa and a focus on deep learning, MLOps, and LLMs.\nI’ve published research on recommender systems and built AI-\ndriven applications like LLM agents, RAG pipelines, and automated\nsummarization tools. Skilled in PyTorch, TensorFlow, Hugging Face,\nDocker, and GCP, I enjoy building end-to-end ML systems that solve\nreal-world problems. I’m currently seeking ML roles where I can\napply my skills and grow with impactful teams.\nExperience\nUniversity of Ottawa\n2 years 10 months\nMachine learning Research Assistant\nSeptember 2022\xa0-\xa0June 2025\xa0 (2 years 10 months)\nOntario, Canada\nTeaching Assistant\nApril 2024\xa0-\xa0August 2024\xa0 (5 months)\nOttawa, Ontario, Canada\nTeaching Assistant\nSeptember 2023\xa0-\xa0December 2023\xa0 (4 months)\nOttawa, Ontario, Canada\nTeacher Assist ...
#  {'role': 'user', 'content': 'do you hold a patent?'}]

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The response is acceptable as it is clear, professional, and engaging. The Agent effectively communicates that Amir Ghadami does not hold any patents while also providing context about his current focus on research and publications. Additionally, the mention of future goals for pursuing patents adds a forward-looking perspective, which is positive. Overall, it aligns well with Amir Ghadami's professional persona.")

# %%
def rerun(reply,message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    message = [{'role': 'system','content': updated_system_prompt}] +history + [{'role':'user', 'content': message}]
    response = openai_client.chat.completions.create(model="gpt-4o-mini", messages=message)
    return response.choices[0].message.content

# %%
def chat(message, history):
    system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai_client.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply = response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        return reply
    else:
        return rerun(reply, message, history, evaluation.feedback)

demo = gr.ChatInterface(chat)
# Out:
# /Users/amir/Desktop/GitHub/new_project/.venv/lib/python3.13/site-packages/gradio/chat_interface.py:347: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   self.chatbot = Chatbot(

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
